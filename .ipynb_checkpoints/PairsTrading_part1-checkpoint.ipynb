# %%
# !pip install pandas-datareader
# !pip install yfinance
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\rajsa\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\rajsa\anaconda3\lib\site-packages (from pandas-datareader) (2.26.0)
# Requirement already satisfied: lxml in c:\users\rajsa\anaconda3\lib\site-packages (from pandas-datareader) (4.6.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\rajsa\appdata\roaming\python\python39\site-packages (from pandas-datareader) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rajsa\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rajsa\appdata\roaming\python\python39\site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\rajsa\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\rajsa\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.4)
# Requirement already satisfied: yfinance in c:\users\rajsa\anaconda3\lib\site-packages (0.1.69)
# Requirement already satisfied: pandas>=0.24 in c:\users\rajsa\appdata\roaming\python\python39\site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\rajsa\anaconda3\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.26 in c:\users\rajsa\anaconda3\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\rajsa\anaconda3\lib\site-packages (from yfinance) (1.20.3)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\rajsa\anaconda3\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rajsa\appdata\roaming\python\python39\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rajsa\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\rajsa\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajsa\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.7)

# %%
import numpy as np
import pandas as pd 
import requests
import matplotlib.pyplot as plt
import xlsxwriter
import math
from pandas_datareader import data as pdr
from datetime import datetime
import os
import yfinance as yf
yf.pdr_override()

# %%
nse200 = pd.read_csv('ind_nifty200list.csv')
for i in range(len(nse200)):
    nse200['Symbol'][i] = nse200['Symbol'][i] + '.NS'
    
list_of_stocks = pd.DataFrame(nse200['Symbol'])
list_of_stocks
# Out:
#             Symbol
# 0           ACC.NS
# 1        AUBANK.NS
# 2      AARTIIND.NS
# 3      ADANIENT.NS
# 4    ADANIGREEN.NS
# ..             ...
# 195      VOLTAS.NS
# 196   WHIRLPOOL.NS
# 197       WIPRO.NS
# 198     YESBANK.NS
# 199        ZEEL.NS
#
# [200 rows x 1 columns]

# %%
start = datetime(2017,1,1)
end = datetime(2022,2,1)

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
#This function returns a pd dataframe with all of the adjusted closing information
def get_historical_Data(tickers):
    data = pd.DataFrame()
    names = list()
    for i in tickers:
        data = pd.concat([data, pd.DataFrame(yf.download(i, start=start, end=end).iloc[:,4])], axis = 1)
        names.append(i)
    data.columns = names
    print(names)
    return data

ticks = nse200['Symbol'].tolist()
d = get_historical_Data(ticks)
print(d.shape)
d.tail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22632/4041874649.py in <module>
#      11
#      12 ticks = nse200['Symbol'].tolist()
# ---> 13 d = get_historical_Data(ticks)
#      14 print(d.shape)
#      15 d.tail()
#
# ~\AppData\Local\Temp/ipykernel_22632/4041874649.py in get_historical_Data(tickers)
#       2 def get_historical_Data(tickers):
#       3     data = pd.DataFrame()
# ----> 4     names = list()
#       5     for i in tickers:
#       6         data = pd.concat([data, pd.DataFrame(yf.download(i, start=start, end=end).iloc[:,4])], axis = 1)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
ticks
# Out:
# ['ACC.NS',
#  'AUBANK.NS',
#  'AARTIIND.NS',
#  'ADANIENT.NS',
#  'ADANIGREEN.NS',
#  'ADANIPORTS.NS',
#  'ATGL.NS',
#  'ADANITRANS.NS',
#  'ABCAPITAL.NS',
#  'ABFRL.NS',
#  'AJANTPHARM.NS',
#  'APLLTD.NS',
#  'ALKEM.NS',
#  'AMARAJABAT.NS',
#  'AMBUJACEM.NS',
#  'APOLLOHOSP.NS',
#  'APOLLOTYRE.NS',
#  'ASHOKLEY.NS',
#  'ASIANPAINT.NS',
#  'ASTRAL.NS',
#  'AUROPHARMA.NS',
#  'DMART.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJFINANCE.NS',
#  'BAJAJFINSV.NS',
#  'BAJAJHLDNG.NS',
#  'BALKRISIND.NS',
#  'BANDHANBNK.NS',
#  'BANKBARODA.NS',
#  'BANKINDIA.NS',
#  'BATAINDIA.NS',
#  'BERGEPAINT.NS',
#  'BEL.NS',
#  'BHARATFORG.NS',
#  'BHEL.NS',
#  'BPCL.NS',
#  'BHARTIARTL.NS',
#  'BIOCON.NS',
#  'BOSCHLTD.NS',
#  'BRITANNIA.NS',
#  'CADILAHC.NS',
#  'CANBK.NS',
#  'CASTROLIND.NS',
#  'CHOLAFIN.NS',
#  'CIPLA.NS',
#  'CUB.NS',
#  'COALINDIA.NS',
#  'COFORGE.NS',
#  'COLPAL.NS',
#  'CONCOR.NS',
#  'COROMANDEL.NS',
#  'CROMPTON.NS',
#  'CUMMINSIND.NS',
#  'DLF.NS',
#  'DABUR.NS',
#  'DALBHARAT.NS',
#  'DEEPAKNTR.NS',
#  'DHANI.NS',
#  'DIVISLAB.NS',
#  'DIXON.NS',
#  'LALPATHLAB.NS',
#  'DRREDDY.NS',
#  'EICHERMOT.NS',
#  'EMAMILTD.NS',
#  'ENDURANCE.NS',
#  'ESCORTS.NS',
#  'EXIDEIND.NS',
#  'FEDERALBNK.NS',
#  'FORTIS.NS',
#  'GAIL.NS',
#  'GLAND.NS',
#  'GLENMARK.NS',
#  'GODREJCP.NS',
#  'GODREJIND.NS',
#  'GODREJPROP.NS',
#  'GRASIM.NS',
#  'GUJGASLTD.NS',
#  'GSPL.NS',
#  'HCLTECH.NS',
#  'HDFCAMC.NS',
#  'HDFCBANK.NS',
#  'HDFCLIFE.NS',
#  'HAVELLS.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'HAL.NS',
#  'HINDCOPPER.NS',
#  'HINDPETRO.NS',
#  'HINDUNILVR.NS',
#  'HINDZINC.NS',
#  'HDFC.NS',
#  'ICICIBANK.NS',
#  'ICICIGI.NS',
#  'ICICIPRULI.NS',
#  'ISEC.NS',
#  'IDFCFIRSTB.NS',
#  'ITC.NS',
#  'INDIAMART.NS',
#  'INDIANB.NS',
#  'INDHOTEL.NS',
#  'IOC.NS',
#  'IRCTC.NS',
#  'IRFC.NS',
#  'IGL.NS',
#  'INDUSTOWER.NS',
#  'INDUSINDBK.NS',
#  'NAUKRI.NS',
#  'INFY.NS',
#  'INDIGO.NS',
#  'IPCALAB.NS',
#  'JSWENERGY.NS',
#  'JSWSTEEL.NS',
#  'JINDALSTEL.NS',
#  'JUBLFOOD.NS',
#  'KOTAKBANK.NS',
#  'L&TFH.NS',
#  'LTTS.NS',
#  'LICHSGFIN.NS',
#  'LTI.NS',
#  'LT.NS',
#  'LAURUSLABS.NS',
#  'LUPIN.NS',
#  'MRF.NS',
#  'MGL.NS',
#  'M&MFIN.NS',
#  'M&M.NS',
#  'MANAPPURAM.NS',
#  'MARICO.NS',
#  'MARUTI.NS',
#  'MFSL.NS',
#  'MINDTREE.NS',
#  'MPHASIS.NS',
#  'MUTHOOTFIN.NS',
#  'NATCOPHARM.NS',
#  'NMDC.NS',
#  'NTPC.NS',
#  'NATIONALUM.NS',
#  'NAVINFLUOR.NS',
#  'NESTLEIND.NS',
#  'NAM-INDIA.NS',
#  'OBEROIRLTY.NS',
#  'ONGC.NS',
#  'OIL.NS',
#  'PIIND.NS',
#  'PAGEIND.NS',
#  'PETRONET.NS',
#  'PFIZER.NS',
#  'PIDILITIND.NS',
#  'PEL.NS',
#  'POLYCAB.NS',
#  'PFC.NS',
#  'POWERGRID.NS',
#  'PRESTIGE.NS',
#  'PGHH.NS',
#  'PNB.NS',
#  'RBLBANK.NS',
#  'RECLTD.NS',
#  'RELIANCE.NS',
#  'SBICARD.NS',
#  'SBILIFE.NS',
#  'SRF.NS',
#  'SANOFI.NS',
#  'SHREECEM.NS',
#  'SRTRANSFIN.NS',
#  'SIEMENS.NS',
#  'SONACOMS.NS',
#  'SBIN.NS',
#  'SAIL.NS',
#  'SUNPHARMA.NS',
#  'SUNTV.NS',
#  'SYNGENE.NS',
#  'TVSMOTOR.NS',
#  'TATACHEM.NS',
#  'TATACOMM.NS',
#  'TCS.NS',
#  'TATACONSUM.NS',
#  'TATAELXSI.NS',
#  'TATAMOTORS.NS',
#  'TATAPOWER.NS',
#  'TATASTEEL.NS',
#  'TECHM.NS',
#  'RAMCOCEM.NS',
#  'TITAN.NS',
#  'TORNTPHARM.NS',
#  'TORNTPOWER.NS',
#  'TRENT.NS',
#  'UPL.NS',
#  'ULTRACEMCO.NS',
#  'UNIONBANK.NS',
#  'UBL.NS',
#  'MCDOWELL-N.NS',
#  'VBL.NS',
#  'VEDL.NS',
#  'IDEA.NS',
#  'VOLTAS.NS',
#  'WHIRLPOOL.NS',
#  'WIPRO.NS',
#  'YESBANK.NS',
#  'ZEEL.NS']

# %%
corr_df = d.corr()
corr_df
# Out:
#                  ACC.NS  AUBANK.NS  AARTIIND.NS  ADANIENT.NS  ADANIGREEN.NS  \
# ACC.NS         1.000000   0.776977     0.782840     0.884705       0.800103
# AUBANK.NS      0.776977   1.000000     0.830286     0.848173       0.791337
# AARTIIND.NS    0.782840   0.830286     1.000000     0.940545       0.902175
# ADANIENT.NS    0.884705   0.848173     0.940545     1.000000       0.885636
# ADANIGREEN.NS  0.800103   0.791337     0.902175     0.885636       1.000000
# ...                 ...        ...          ...          ...            ...
# VOLTAS.NS      0.865607   0.897721     0.933296     0.933902       0.910388
# WHIRLPOOL.NS   0.377398   0.661612     0.717922     0.546401       0.613191
# WIPRO.NS       0.905798   0.835829     0.944984     0.970409       0.880185
# YESBANK.NS    -0.349498  -0.560052    -0.764404    -0.581512      -0.615493
# ZEEL.NS       -0.207344  -0.428128    -0.654092    -0.451101      -0.461191
#
#                ADANIPORTS.NS   ATGL.NS  ADANITRANS.NS  ABCAPITAL.NS  ABFRL.NS  \
# ACC.NS              0.900493  0.898282       0.875064      0.257753  0.589153
# AUBANK.NS           0.840200  0.772282       0.805458      0.028440  0.600530
# AARTIIND.NS         0.859269  0.946201       0.915600     -0.244557  0.529501
# ADANIENT.NS         0.946607  0.978730       0.973372      0.008184  0.566182
# ADANIGREEN.NS       0.859305  0.854445       0.847323      0.270354  0.249386
# ...                      ...       ...            ...           ...       ...
# VOLTAS.NS           0.923810  0.923960       0.927275      0.012270  0.596505
# WHIRLPOOL.NS        0.516619  0.322047       0.513258     -0.442101  0.258915
# WIPRO.NS            0.923113  0.942889       0.951050     -0.030462  0.579378
# YESBANK.NS         -0.467630 -0.449060      -0.544468      0.707849 -0.315575
# ZEEL.NS            -0.342208 -0.099034      -0.388638      0.757890 -0.123753
#
#                ...    UBL.NS  MCDOWELL-N.NS    VBL.NS   VEDL.NS   IDEA.NS  \
# ACC.NS         ...  0.580450       0.615420  0.768260  0.814887 -0.190306
# AUBANK.NS      ...  0.578852       0.550176  0.872694  0.563207 -0.406031
# AARTIIND.NS    ...  0.676056       0.640529  0.976137  0.508979 -0.652099
# ADANIENT.NS    ...  0.614312       0.623251  0.912445  0.719259 -0.423812
# ADANIGREEN.NS  ...  0.286948       0.519615  0.893466  0.710763 -0.281831
# ...            ...       ...            ...       ...       ...       ...
# VOLTAS.NS      ...  0.697572       0.707572  0.945380  0.640080 -0.514142
# WHIRLPOOL.NS   ...  0.459635       0.415308  0.772515  0.008805 -0.763218
# WIPRO.NS       ...  0.676699       0.641715  0.925971  0.689301 -0.462820
# YESBANK.NS     ... -0.439372      -0.294301 -0.781580  0.078655  0.872288
# ZEEL.NS        ... -0.264130      -0.085418 -0.662142  0.247193  0.859082
#
#                VOLTAS.NS  WHIRLPOOL.NS  WIPRO.NS  YESBANK.NS   ZEEL.NS
# ACC.NS          0.865607      0.377398  0.905798   -0.349498 -0.207344
# AUBANK.NS       0.897721      0.661612  0.835829   -0.560052 -0.428128
# AARTIIND.NS     0.933296      0.717922  0.944984   -0.764404 -0.654092
# ADANIENT.NS     0.933902      0.546401  0.970409   -0.581512 -0.451101
# ADANIGREEN.NS   0.910388      0.613191  0.880185   -0.615493 -0.461191
# ...                  ...           ...       ...         ...       ...
# VOLTAS.NS       1.000000      0.704619  0.951674   -0.637787 -0.490121
# WHIRLPOOL.NS    0.704619      1.000000  0.569463   -0.817133 -0.799919
# WIPRO.NS        0.951674      0.569463  1.000000   -0.605489 -0.463550
# YESBANK.NS     -0.637787     -0.817133 -0.605489    1.000000  0.936671
# ZEEL.NS        -0.490121     -0.799919 -0.463550    0.936671  1.000000
#
# [200 rows x 200 columns]

# %%
corr_matrix = corr_df.to_numpy()
corr_matrix
# Out:
# array([[ 1.        ,  0.77697715,  0.78284011, ...,  0.90579772,
#         -0.34949778, -0.20734397],
#        [ 0.77697715,  1.        ,  0.83028561, ...,  0.83582855,
#         -0.56005224, -0.42812822],
#        [ 0.78284011,  0.83028561,  1.        , ...,  0.94498423,
#         -0.7644044 , -0.65409167],
#        ...,
#        [ 0.90579772,  0.83582855,  0.94498423, ...,  1.        ,
#         -0.60548899, -0.46355021],
#        [-0.34949778, -0.56005224, -0.7644044 , ..., -0.60548899,
#          1.        ,  0.93667111],
#        [-0.20734397, -0.42812822, -0.65409167, ..., -0.46355021,
#          0.93667111,  1.        ]])

# %%
threshold = 0.98

corr_pairs = []
for i in range(corr_matrix.shape[0]):
    for j in range(i+1, corr_matrix.shape[1]):
        if corr_matrix[i,j] > threshold:
            corr_pairs.append([i,j])

print('Total number of correlation pairs = ',len(corr_pairs))
# Out:
# Total number of correlation pairs =  14

# %%
filtered_df = corr_df[(corr_df > threshold) & (corr_df !=1.000)]
filtered_df
# Out:
#                ACC.NS  AUBANK.NS  AARTIIND.NS  ADANIENT.NS  ADANIGREEN.NS  \
# ACC.NS            NaN        NaN          NaN          NaN            NaN
# AUBANK.NS         NaN        NaN          NaN          NaN            NaN
# AARTIIND.NS       NaN        NaN          NaN          NaN            NaN
# ADANIENT.NS       NaN        NaN          NaN          NaN            NaN
# ADANIGREEN.NS     NaN        NaN          NaN          NaN            NaN
# ...               ...        ...          ...          ...            ...
# VOLTAS.NS         NaN        NaN          NaN          NaN            NaN
# WHIRLPOOL.NS      NaN        NaN          NaN          NaN            NaN
# WIPRO.NS          NaN        NaN          NaN          NaN            NaN
# YESBANK.NS        NaN        NaN          NaN          NaN            NaN
# ZEEL.NS           NaN        NaN          NaN          NaN            NaN
#
#                ADANIPORTS.NS  ATGL.NS  ADANITRANS.NS  ABCAPITAL.NS  ABFRL.NS  \
# ACC.NS                   NaN      NaN            NaN           NaN       NaN
# AUBANK.NS                NaN      NaN            NaN           NaN       NaN
# AARTIIND.NS              NaN      NaN            NaN           NaN       NaN
# ADANIENT.NS              NaN      NaN            NaN           NaN       NaN
# ADANIGREEN.NS            NaN      NaN            NaN           NaN       NaN
# ...                      ...      ...            ...           ...       ...
# VOLTAS.NS                NaN      NaN            NaN           NaN       NaN
# WHIRLPOOL.NS             NaN      NaN            NaN           NaN       NaN
# WIPRO.NS                 NaN      NaN            NaN           NaN       NaN
# YESBANK.NS               NaN      NaN            NaN           NaN       NaN
# ZEEL.NS                  NaN      NaN            NaN           NaN       NaN
#
#                ...  UBL.NS  MCDOWELL-N.NS  VBL.NS  VEDL.NS  IDEA.NS  \
# ACC.NS         ...     NaN            NaN     NaN      NaN      NaN
# AUBANK.NS      ...     NaN            NaN     NaN      NaN      NaN
# AARTIIND.NS    ...     NaN            NaN     NaN      NaN      NaN
# ADANIENT.NS    ...     NaN            NaN     NaN      NaN      NaN
# ADANIGREEN.NS  ...     NaN            NaN     NaN      NaN      NaN
# ...            ...     ...            ...     ...      ...      ...
# VOLTAS.NS      ...     NaN            NaN     NaN      NaN      NaN
# WHIRLPOOL.NS   ...     NaN            NaN     NaN      NaN      NaN
# WIPRO.NS       ...     NaN            NaN     NaN      NaN      NaN
# YESBANK.NS     ...     NaN            NaN     NaN      NaN      NaN
# ZEEL.NS        ...     NaN            NaN     NaN      NaN      NaN
#
#                VOLTAS.NS  WHIRLPOOL.NS  WIPRO.NS  YESBANK.NS  ZEEL.NS
# ACC.NS               NaN           NaN       NaN         NaN      NaN
# AUBANK.NS            NaN           NaN       NaN         NaN      NaN
# AARTIIND.NS          NaN           NaN       NaN         NaN      NaN
# ADANIENT.NS          NaN           NaN       NaN         NaN      NaN
# ADANIGREEN.NS        NaN           NaN       NaN         NaN      NaN
# ...                  ...           ...       ...         ...      ...
# VOLTAS.NS            NaN           NaN       NaN         NaN      NaN
# WHIRLPOOL.NS         NaN           NaN       NaN         NaN      NaN
# WIPRO.NS             NaN           NaN       NaN         NaN      NaN
# YESBANK.NS           NaN           NaN       NaN         NaN      NaN
# ZEEL.NS              NaN           NaN       NaN         NaN      NaN
#
# [200 rows x 200 columns]

# %%
# filteredDf = dfCorr[((dfCorr >= .5) | (dfCorr <= -.5)) & (dfCorr !=1.000)]
import seaborn as sn
plt.figure(figsize=(24,12))
sn.heatmap(filtered_df, annot=True, cmap="Reds")
plt.show()

# %%
sorted_mat = filtered_df.unstack().sort_values().drop_duplicates().dropna()
sorted_mat
# Out:
# MPHASIS.NS     COFORGE.NS       0.980692
# AARTIIND.NS    PIDILITIND.NS    0.981108
# ADANIENT.NS    DEEPAKNTR.NS     0.981371
# MINDTREE.NS    LTTS.NS          0.981613
# DIVISLAB.NS    PIIND.NS         0.981620
# SRF.NS         COFORGE.NS       0.981709
# TECHM.NS       LTTS.NS          0.981776
# PIDILITIND.NS  VBL.NS           0.982394
# PNB.NS         UNIONBANK.NS     0.983384
# DIVISLAB.NS    NAUKRI.NS        0.983756
# PIIND.NS       LALPATHLAB.NS    0.984400
# ATGL.NS        ADANITRANS.NS    0.987070
# INFY.NS        HCLTECH.NS       0.987207
# MINDTREE.NS    MPHASIS.NS       0.987940
# dtype: float64

# %%
file_name = 'stocmks.xlsx'
  
# saving the excel
sorted_mat.to_csv(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
df2 = pd.read_csv('stocmks.xlsx')

# %%
my_columns = ("Stock_1","Stock_2","Corr")
df2.columns =  my_columns
df3  = df2.to_numpy()
print(df3)
# Out:
# [['MPHASIS.NS' 'COFORGE.NS' 0.9806922660285384]
#  ['AARTIIND.NS' 'PIDILITIND.NS' 0.9811081796358586]
#  ['ADANIENT.NS' 'DEEPAKNTR.NS' 0.9813713395112382]
#  ['MINDTREE.NS' 'LTTS.NS' 0.981613432095302]
#  ['DIVISLAB.NS' 'PIIND.NS' 0.9816202594389728]
#  ['SRF.NS' 'COFORGE.NS' 0.98170907554785]
#  ['TECHM.NS' 'LTTS.NS' 0.9817764172165612]
#  ['PIDILITIND.NS' 'VBL.NS' 0.982393965148044]
#  ['PNB.NS' 'UNIONBANK.NS' 0.983384289809097]
#  ['DIVISLAB.NS' 'NAUKRI.NS' 0.9837564726456844]
#  ['PIIND.NS' 'LALPATHLAB.NS' 0.9843995964532064]
#  ['ATGL.NS' 'ADANITRANS.NS' 0.987070359980228]
#  ['INFY.NS' 'HCLTECH.NS' 0.9872068646654966]
#  ['MINDTREE.NS' 'MPHASIS.NS' 0.987939912692868]]

# %%
comp_set1 = pd.DataFrame(df2["Stock_1"])
comp_set1
# Out:
#           Stock_1
# 0      MPHASIS.NS
# 1     AARTIIND.NS
# 2     ADANIENT.NS
# 3     MINDTREE.NS
# 4     DIVISLAB.NS
# 5          SRF.NS
# 6        TECHM.NS
# 7   PIDILITIND.NS
# 8          PNB.NS
# 9     DIVISLAB.NS
# 10       PIIND.NS
# 11        ATGL.NS
# 12        INFY.NS
# 13    MINDTREE.NS

# %%
comp_set2 = pd.DataFrame(df2["Stock_2"])
comp_set2
# Out:
#           Stock_2
# 0      COFORGE.NS
# 1   PIDILITIND.NS
# 2    DEEPAKNTR.NS
# 3         LTTS.NS
# 4        PIIND.NS
# 5      COFORGE.NS
# 6         LTTS.NS
# 7          VBL.NS
# 8    UNIONBANK.NS
# 9       NAUKRI.NS
# 10  LALPATHLAB.NS
# 11  ADANITRANS.NS
# 12     HCLTECH.NS
# 13     MPHASIS.NS

# %%
lists1 = []
lists2 = []
for list in df3:
    lists1.append(list[0])
    lists2.append(list[1])
unique_stock_list = lists1[:]
[unique_stock_list.append(i) for i in lists2 if i not in lists1]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None]

# %%
# def find_cointegrated_pairs(data):
#     n = data.shape[1]
#     score_matrix = np.zeros((n, n))
#     pvalue_matrix = np.ones((n, n))
#     keys = data.keys()
#     pairs = []
#     for i in range(n):
#         for j in range(i+1, n):
#             S1 = data[keys[i]]
#             S2 = data[keys[j]]
#             result = coint(S1, S2)
#             score = result[0]
#             pvalue = result[1]
#             score_matrix[i, j] = score
#             pvalue_matrix[i, j] = pvalue
#             if pvalue < 0.05:
#                 pairs.append((keys[i], keys[j]))
#     return score_matrix, pvalue_matrix, pairs

# %%
df_final_stocks = pd.DataFrame(unique_stock_list)
df_final_stocks
# Out:
#                 0
# 0      MPHASIS.NS
# 1     AARTIIND.NS
# 2     ADANIENT.NS
# 3     MINDTREE.NS
# 4     DIVISLAB.NS
# 5          SRF.NS
# 6        TECHM.NS
# 7   PIDILITIND.NS
# 8          PNB.NS
# 9     DIVISLAB.NS
# 10       PIIND.NS
# 11        ATGL.NS
# 12        INFY.NS
# 13    MINDTREE.NS
# 14     COFORGE.NS
# 15   DEEPAKNTR.NS
# 16        LTTS.NS
# 17     COFORGE.NS
# 18        LTTS.NS
# 19         VBL.NS
# 20   UNIONBANK.NS
# 21      NAUKRI.NS
# 22  LALPATHLAB.NS
# 23  ADANITRANS.NS
# 24     HCLTECH.NS

# %%
my_column1 = ["Symbl"]
df_final_stocks.columns = my_column1

# %%
df_final_stocks.to_csv('final_stocks_data.csv', index=False)

# %%
df_final_stocks
# Out:
#             Symbl
# 0      MPHASIS.NS
# 1     AARTIIND.NS
# 2     ADANIENT.NS
# 3     MINDTREE.NS
# 4     DIVISLAB.NS
# 5          SRF.NS
# 6        TECHM.NS
# 7   PIDILITIND.NS
# 8          PNB.NS
# 9     DIVISLAB.NS
# 10       PIIND.NS
# 11        ATGL.NS
# 12        INFY.NS
# 13    MINDTREE.NS
# 14     COFORGE.NS
# 15   DEEPAKNTR.NS
# 16        LTTS.NS
# 17     COFORGE.NS
# 18        LTTS.NS
# 19         VBL.NS
# 20   UNIONBANK.NS
# 21      NAUKRI.NS
# 22  LALPATHLAB.NS
# 23  ADANITRANS.NS
# 24     HCLTECH.NS
